# %%
import os
import sys

import numpy as np
import pandas as pd
import warnings

from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")
sys.path.append(os.path.abspath(os.path.join("modelling", '../..')))

from utility import plot

# %%
PLOT_DPI = 100
SEED = 42

DATA_FILE = "../data/preprocessed_skab_dataset_fe.csv"

# %%
dataframe = pd.read_csv(DATA_FILE)
dataframe.set_index(pd.to_datetime(dataframe.datetime), drop=True, inplace=True)
dataframe.drop(columns=["datetime"], inplace=True)
dataframe
# Out:
#                      Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  \
# datetime
# 2020-02-08 13:30:47           0.202394           0.275154  2.169750  1.402774
# 2020-02-08 13:30:48           0.203153           0.277857  2.079990  0.746920
# 2020-02-08 13:30:49           0.203153           0.277857  2.079990  0.746920
# 2020-02-08 13:30:50           0.202054           0.275790  2.525770  1.402774
# 2020-02-08 13:30:51           0.203595           0.278101  2.497420  1.074847
# ...                                ...                ...       ...       ...
# 2020-03-09 17:14:05           0.027067           0.038430  0.988875  1.073357
# 2020-03-09 17:14:06           0.027067           0.038430  0.988875  1.073357
# 2020-03-09 17:14:07           0.027582           0.038836  0.588439  1.073357
# 2020-03-09 17:14:08           0.027406           0.038133  0.989732  0.745430
# 2020-03-09 17:14:09           0.027102           0.039890  0.558126  0.745430
#
#                      Temperature  Thermocouple  Voltage  Volume Flow RateRMS  \
# datetime
# 2020-02-08 13:30:47      90.6454       26.8508  238.852             122.6640
# 2020-02-08 13:30:48      90.7978       26.8639  227.943             122.3380
# 2020-02-08 13:30:49      90.7978       26.8639  227.943             122.3380
# 2020-02-08 13:30:50      90.7730       26.8603  223.486             121.3380
# 2020-02-08 13:30:51      90.8424       26.8616  244.904             121.6640
# ...                          ...           ...      ...                  ...
# 2020-03-09 17:14:05      69.6731       24.1046  230.729              32.9562
# 2020-03-09 17:14:06      69.6731       24.1046  230.729              32.9562
# 2020-03-09 17:14:07      69.6959       24.1020  233.443              32.0000
# 2020-03-09 17:14:08      69.6293       24.1020  238.930              32.0000
# 2020-03-09 17:14:09      69.7253       24.0972  219.653              32.0000
#
#                      Electrical_Resistence  Flow_Resistance  ...  \
# datetime                                                     ...
# 2020-02-08 13:30:47             110.082728         0.011436  ...
# 2020-02-08 13:30:48             109.588508         0.006105  ...
# 2020-02-08 13:30:49             109.588508         0.006105  ...
# 2020-02-08 13:30:50              88.482324         0.011561  ...
# 2020-02-08 13:30:51              98.062801         0.008835  ...
# ...                                    ...              ...  ...
# 2020-03-09 17:14:05             233.324738         0.032569  ...
# 2020-03-09 17:14:06             233.324738         0.032569  ...
# 2020-03-09 17:14:07             396.715717         0.033542  ...
# 2020-03-09 17:14:08             241.408785         0.023295  ...
# 2020-03-09 17:14:09             393.554502         0.023295  ...
#
#                      Temperature_Difference  Hydraulic_Power  \
# datetime
# 2020-03-09 17:14:08                                 0.004344      0.0
# 2020-03-09 17:14:09                                 0.008362      0.0
#
#                      description
# datetime
# 2020-02-08 13:30:47   No Anomaly
# 2020-02-08 13:30:48   No Anomaly
# 2020-02-08 13:30:49   No Anomaly
# 2020-02-08 13:30:50   No Anomaly
# 2020-02-08 13:30:51   No Anomaly
# ...                          ...
# 2020-03-09 17:14:05   No Anomaly
# 2020-03-09 17:14:06   No Anomaly
# 2020-03-09 17:14:07   No Anomaly
# 2020-03-09 17:14:08   No Anomaly
# 2020-03-09 17:14:09   No Anomaly
#
# [49202 rows x 24 columns]

# %%
dataframe_X = dataframe.drop(columns=["anomaly"])
dataframe_y = dataframe[["anomaly"]]

# %%
plot.categorical_distribution(
                                dataframe_X, 
                                column_name="description", 
                                title="Distribution_Of_Anomalies_Complete_Dataset", 
                                save=False,
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                                        dataframe_X.values, 
                                                        dataframe_y.values.ravel(), 
                                                        test_size=0.3, 
                                                        random_state=SEED, 
                                                        stratify=dataframe_y.values.ravel()
)
dataframe_X_train = pd.DataFrame(X_train, columns=dataframe_X.columns)
dataframe_X_test = pd.DataFrame(X_test, columns=dataframe_X.columns)
dataframe_y_train = pd.DataFrame(y_train, columns=dataframe_y.columns)
dataframe_y_test = pd.DataFrame(y_test, columns=dataframe_y.columns)

X_val, X_test, y_val, y_test = train_test_split(
                                                        dataframe_X_test.values, 
                                                        dataframe_y_test.values.ravel(), 
                                                        test_size=0.5, 
                                                        random_state=SEED, 
                                                        stratify=dataframe_y_test.values.ravel()
)
dataframe_X_val = pd.DataFrame(X_val, columns=dataframe_X.columns)
dataframe_X_test = pd.DataFrame(X_test, columns=dataframe_X.columns)
dataframe_y_val = pd.DataFrame(y_val, columns=dataframe_y.columns)
dataframe_y_test = pd.DataFrame(y_test, columns=dataframe_y.columns)

# %%
plot.categorical_distribution(
                                dataframe_X_train, 
                                column_name="description", 
                                title="Distribution_Of_Anomalies_Training_Set", 
                                save=False,
)
plot.categorical_distribution(
                                dataframe_X_val, 
                                column_name="description", 
                                title="Distribution_Of_Anomalies_Validation_Set", 
                                save=False,
)
plot.categorical_distribution(
                                dataframe_X_test, 
                                column_name="description", 
                                title="Distribution_Of_Anomalies_Test_Set", 
                                save=False,
)

# %%
pd.concat([dataframe_X_train, dataframe_y_train], axis=1).to_csv(
    "../data/preprocessed_skab_dataset_fe_train.csv", 
    index=False
)
pd.concat([dataframe_X_val, dataframe_y_val], axis=1).to_csv(
    "../data/preprocessed_skab_dataset_fe_val.csv", 
    index=False
)
pd.concat([dataframe_X_test, dataframe_y_test], axis=1).to_csv(
    "../data/preprocessed_skab_dataset_fe_test.csv", 
    index=False
)
