# %%
import os
import sys

import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings("ignore")
sys.path.append(os.path.abspath(os.path.join("modelling", '../..')))

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from imblearn.over_sampling import ADASYN

# %%
SEED = 42
PLOT_DPI = 100

# TRAIN_DATA_FILE = "../data/preprocessed_skab_dataset_fe_train.csv"
# SAVE_DATA_FILE = "../data/preprocessed_skab_dataset_train_adasyn.csv"

TRAIN_DATA_FILE = "../data/preprocessed_skab_dataset_train_undersampled.csv"
SAVE_DATA_FILE = "../data/preprocessed_skab_dataset_train_undersampled_adasyn.csv"

USE_FE = False

# %%
dataframe_train = pd.read_csv(TRAIN_DATA_FILE)

if not USE_FE:
    og_columns = ["Accelerometer1RMS", "Accelerometer2RMS", "Current", "Pressure", "Temperature", "Thermocouple", "Voltage", "Volume Flow RateRMS", "anomaly", "description"]
    dataframe_train = dataframe_train.drop(columns=[col for col in dataframe_train.columns if col not in og_columns])

dataframe_train
# Out:
#        Accelerometer1RMS  Accelerometer2RMS  Current  Pressure  Temperature  \
# 0               0.219595           0.267058  2.97205  1.074847      88.9166
# 1               0.028225           0.042124  1.43210  1.401284      68.6462
# 2               0.214053           0.259569  2.22898  1.730701      88.2787
# 3               0.255422           0.294430  2.99871  1.074847      86.2073
# 4               0.081667           0.129274  1.56118  0.733489      87.2407
# ...                  ...                ...      ...       ...          ...
# 31444           0.232582           0.301550  2.55280  1.074847      84.6528
# 31445           0.234111           0.298961  2.67178  1.074847      85.2649
# 31446           0.231709           0.301727  2.64041  1.730701      84.5624
# 31447           0.233409           0.303753  2.08954  1.074847      84.6937
# 31448           0.232973           0.300715  2.67952  1.074847      85.0247
#
#        Thermocouple  Voltage  Volume Flow RateRMS  \
# 0           28.9319  227.339             127.0000
# 1           24.7640  245.677              32.9805
# 2           29.6790  227.822             127.0000
# 3           28.8126  232.379             126.0000
# 4           22.1358  234.136              77.0000
# ...             ...      ...                  ...
# 31444       30.2489  243.604             125.6900
# 31445       30.1380  232.345             128.3120
# 31446       30.0042  234.070             129.3120
# 31447       30.1634  236.700             130.0000
# 31448       30.1936  226.760             126.0000
#
#                           description  anomaly
# 0                          No Anomaly      0.0
# 1                          No Anomaly      0.0
# 2                          No Anomaly      0.0
# 3                          No Anomaly      0.0
# 4                          No Anomaly      0.0
# ...                               ...      ...
# 31444  Sharp Water Increase (Circuit)      7.0
# 31445  Sharp Water Increase (Circuit)      7.0
# 31446  Sharp Water Increase (Circuit)      7.0
# 31447  Sharp Water Increase (Circuit)      7.0
# 31448  Sharp Water Increase (Circuit)      7.0
#
# [31449 rows x 10 columns]

# %%
adasyn = ADASYN(random_state=SEED)
X_res_adasyn, y_res_adasyn = adasyn.fit_resample(dataframe_train.drop(columns=["anomaly", "description"]), dataframe_train.anomaly.values)

X_res_adasyn.shape, y_res_adasyn.shape
# Out:
# ((315072, 8), (315072,))

# %%
dataframe_train_adasyn = pd.DataFrame(X_res_adasyn, columns=dataframe_train.drop(columns=["anomaly", "description"]).columns)
dataframe_train_adasyn["anomaly"] = y_res_adasyn

dataframe_train_adasyn
# Out:
#         Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  Temperature  \
# 0                0.219595           0.267058  2.972050  1.074847    88.916600
# 1                0.028225           0.042124  1.432100  1.401284    68.646200
# 2                0.214053           0.259569  2.228980  1.730701    88.278700
# 3                0.255422           0.294430  2.998710  1.074847    86.207300
# 4                0.081667           0.129274  1.561180  0.733489    87.240700
# ...                   ...                ...       ...       ...          ...
# 315067           0.027704           0.039343  1.344266  1.073357    68.326432
# 315068           0.027842           0.039306  1.293933  0.708068    68.487890
# 315069           0.027770           0.039147  1.342642  0.989258    68.399912
# 315070           0.028059           0.039282  1.427767  0.665181    68.151853
# 315071           0.028124           0.039320  1.442441  0.580292    68.105737
#
#         Thermocouple     Voltage  Volume Flow RateRMS  anomaly
# 0          28.931900  227.339000           127.000000      0.0
# 1          24.764000  245.677000            32.980500      0.0
# 2          29.679000  227.822000           127.000000      0.0
# 3          28.812600  232.379000           126.000000      0.0
# 4          22.135800  234.136000            77.000000      0.0
# ...              ...         ...                  ...      ...
# 315067     24.175142  240.391006            30.042671     13.0
# 315068     24.216480  240.660534            29.997251     13.0
# 315069     24.185397  240.464600            30.032237     13.0
# 315070     24.174544  240.554744            30.042513     13.0
# 315071     24.174221  240.585678            30.042474     13.0
#
# [315072 rows x 9 columns]

# %%
print("\nDataset after SMOTE:")
print(f"Total samples: {len(y_res_adasyn)}")
unique, counts = np.unique(y_res_adasyn, return_counts=True)
print(f"Class distribution: {dict(zip(unique, counts))}")
# Out:
# Dataset after SMOTE:
# Total samples: 315072
# Class distribution: {np.float64(0.0): np.int64(22514), np.float64(1.0): np.int64(22539), np.float64(2.0): np.int64(22504), np.float64(3.0): np.int64(22503), np.float64(4.0): np.int64(22465), np.float64(5.0): np.int64(22514), np.float64(6.0): np.int64(22524), np.float64(7.0): np.int64(22485), np.float64(8.0): np.int64(22514), np.float64(9.0): np.int64(22479), np.float64(10.0): np.int64(22526), np.float64(11.0): np.int64(22487), np.float64(12.0): np.int64(22232), np.float64(13.0): np.int64(22786)}

# %%
columns = dataframe_train.drop(columns=["anomaly", "description"]).columns
for idx, col in enumerate(columns):
    print(f"{idx}: {col}")
# Out:
# 0: Accelerometer1RMS
# 1: Accelerometer2RMS
# 2: Current
# 3: Pressure
# 4: Temperature
# 5: Thermocouple
# 6: Voltage
# 7: Volume Flow RateRMS

# %%
col1, col2 = columns[2], columns[4]

fig, axs = plt.subplots(1, 2, figsize=(20, 6), dpi=PLOT_DPI)

axs[0].set_title("Original Imbalanced Dataset")
for class_label in np.unique(dataframe_train.anomaly):
    axs[0].scatter(
                    dataframe_train[dataframe_train.anomaly == class_label][col1], 
                    dataframe_train[dataframe_train.anomaly == class_label][col2], 
                    label=f'Class {class_label}', alpha=0.5, s=20 if class_label == 0 else 40
    )
axs[0].legend()
axs[0].grid(True, linestyle='--', alpha=0.6)

axs[1].set_title("Dataset after adasyn")
for class_label in np.unique(dataframe_train_adasyn.anomaly):
    axs[1].scatter(
                    dataframe_train_adasyn[dataframe_train_adasyn.anomaly == class_label][col1], 
                    dataframe_train_adasyn[dataframe_train_adasyn.anomaly == class_label][col2], 
                    label=f'Class {class_label}', alpha=0.5, s=20 if class_label == 0 else 40
    )
axs[1].legend()
axs[1].grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
dataframe_train_adasyn.shape
# Out:
# (315072, 9)

# %%
dataframe_train_adasyn.head()
# Out:
#    Accelerometer1RMS  Accelerometer2RMS  Current  Pressure  Temperature  \
# 0           0.219595           0.267058  2.97205  1.074847      88.9166
# 1           0.028225           0.042124  1.43210  1.401284      68.6462
# 2           0.214053           0.259569  2.22898  1.730701      88.2787
# 3           0.255422           0.294430  2.99871  1.074847      86.2073
# 4           0.081667           0.129274  1.56118  0.733489      87.2407
#
#    Thermocouple  Voltage  Volume Flow RateRMS  anomaly
# 0       28.9319  227.339             127.0000      0.0
# 1       24.7640  245.677              32.9805      0.0
# 2       29.6790  227.822             127.0000      0.0
# 3       28.8126  232.379             126.0000      0.0
# 4       22.1358  234.136              77.0000      0.0

# %%
anomaly_ids = dict()
for idx, desc in zip(dataframe_train.anomaly, dataframe_train.description):
    anomaly_ids[idx] = desc


for idx, desc in anomaly_ids.items():
    print(f"{idx}: {desc}")
# Out:
# 0.0: No Anomaly
# 12.0: Inlet Valve Malfunction
# 8.0: Water Drainage (Cavitation)
# 11.0: Fluid Leaks
# 13.0: Outlet Valve Malfunction
# 2.0: Linear - Rotor Imbalance
# 1.0: Sharp - Rotor Imbalance
# 5.0: Exponential - Rotor Imbalance
# 3.0: Step - Rotor Imbalance
# 6.0: Slow Water Increase (Circuit)
# 4.0: Dirac - Rotor Imbalance
# 9.0: Two-phase Supply (Cavitation)
# 10.0: Water Temperature Increase
# 7.0: Sharp Water Increase (Circuit)

# %%
desc = list()
for idx in dataframe_train_adasyn.anomaly:
    desc.append(anomaly_ids[idx])

dataframe_train_adasyn["description"] = desc
dataframe_train_adasyn
# Out:
#         Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  Temperature  \
# 0                0.219595           0.267058  2.972050  1.074847    88.916600
# 1                0.028225           0.042124  1.432100  1.401284    68.646200
# 2                0.214053           0.259569  2.228980  1.730701    88.278700
# 3                0.255422           0.294430  2.998710  1.074847    86.207300
# 4                0.081667           0.129274  1.561180  0.733489    87.240700
# ...                   ...                ...       ...       ...          ...
# 315067           0.027704           0.039343  1.344266  1.073357    68.326432
# 315068           0.027842           0.039306  1.293933  0.708068    68.487890
# 315069           0.027770           0.039147  1.342642  0.989258    68.399912
# 315070           0.028059           0.039282  1.427767  0.665181    68.151853
# 315071           0.028124           0.039320  1.442441  0.580292    68.105737
#
#         Thermocouple     Voltage  Volume Flow RateRMS  anomaly  \
# 0          28.931900  227.339000           127.000000      0.0
# 1          24.764000  245.677000            32.980500      0.0
# 2          29.679000  227.822000           127.000000      0.0
# 3          28.812600  232.379000           126.000000      0.0
# 4          22.135800  234.136000            77.000000      0.0
# ...              ...         ...                  ...      ...
# 315067     24.175142  240.391006            30.042671     13.0
# 315068     24.216480  240.660534            29.997251     13.0
# 315069     24.185397  240.464600            30.032237     13.0
# 315070     24.174544  240.554744            30.042513     13.0
# 315071     24.174221  240.585678            30.042474     13.0
#
#                      description
# 0                     No Anomaly
# 1                     No Anomaly
# 2                     No Anomaly
# 3                     No Anomaly
# 4                     No Anomaly
# ...                          ...
# 315067  Outlet Valve Malfunction
# 315068  Outlet Valve Malfunction
# 315069  Outlet Valve Malfunction
# 315070  Outlet Valve Malfunction
# 315071  Outlet Valve Malfunction
#
# [315072 rows x 10 columns]

# %%
dataframe_train_adasyn.to_csv(SAVE_DATA_FILE, index=False)
