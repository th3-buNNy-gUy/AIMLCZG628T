# %%
import os
import sys

import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings("ignore")
sys.path.append(os.path.abspath(os.path.join("modelling", '../..')))

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from imblearn.over_sampling import ADASYN

# %%
SEED = 42
PLOT_DPI = 100

TRAIN_DATA_FILE = "../../datasets/Skoltech_Anomaly_Benchmark/preprocessed_skab_dataset_set2_test.csv"

USE_LDA = False

# %%
dataframe_train = pd.read_csv(TRAIN_DATA_FILE)
dataframe_train
# Out:
#       Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  Temperature  \
# 0              0.210323           0.262893  2.658640  1.074847      88.6217
# 1              0.028297           0.042536  0.814120  0.745430      68.0318
# 2              0.028185           0.041387  0.810610  1.073357      68.8750
# 3              0.027955           0.042217  1.125930  1.073357      68.9973
# 4              0.211749           0.272061  2.654510  1.402774      90.2739
# ...                 ...                ...       ...       ...          ...
# 7376           0.027119           0.039793  1.145980  1.073357      69.6155
# 7377           0.209236           0.261347  2.532400  1.074847      88.9830
# 7378           0.027496           0.039704  0.618982  1.073357      68.3109
# 7379           0.243079           0.287370  2.320710  1.402774      85.5501
# 7380           0.027826           0.038374  1.185520  1.073357      68.5264
#
#       Thermocouple  Voltage  Volume Flow RateRMS  Electrical_Resistence  \
# 0          29.3147  230.091             126.6770              86.544624
# 1          24.2354  232.174              32.0000             285.184002
# 2          24.7075  208.422              32.0000             257.117479
# 3          24.7679  235.556              27.0000             209.210164
# 4          27.8473  225.678             123.6680              85.016820
# ...            ...      ...                  ...                    ...
# 7376       24.9792  230.324              31.0000             200.984310
# 7377       29.1743  222.902             126.0000              88.020060
# 7378       24.4975  229.008              32.0317             369.975217
# 7379       29.4859  250.139             127.3840             107.785548
# 7380       24.6420  242.575              31.0263             204.614853
#
#       Flow_Resistance  ...  Engine_Temperature_pu_Power  \
# 0            0.008485  ...                     0.170436
# 1            0.023295  ...                     0.423439
# 2            0.033542  ...                     0.479609
# 3            0.039754  ...                     0.306061
# 4            0.011343  ...                     0.177284
# ...               ...  ...                          ...
# 7376         0.034624  ...                     0.310292
# 7377         0.008531  ...                     0.185456
# 7378         0.033509  ...                     0.566947
# 7379         0.011012  ...                     0.173380
# 7380         0.034595  ...                     0.280339
#
#       Efficiency_Temperature_Difference_Ratio  AccelerometerRMS_Fluctuation  \
# 0                                    0.007359                      0.000450
# 1                                    0.005650                      0.000042
# 2                                    0.009025                      0.000026
# 3                                    0.004844                      0.000024
# 4                                    0.009096                      0.000340
# ...                                       ...                           ...
# 7376                                 0.005538                      0.000017
# 7377                                 0.007866                      0.000314
# 7378                                 0.010855                      0.000030
# 7379                                 0.010766                      0.001260
# 7380                                 0.005174                      0.000036
#
#       Temperature_Fluctuation  Thermocouple_Fluctuation  \
# 0                    0.115096                  0.005824
# 1                    0.111232                  0.004348
# 2                    0.029276                  0.006124
# 3                    0.018756                  0.002284
# 4                    0.075920                  0.004140
# ...                       ...                       ...
# 7376                 0.051492                  0.003720
# 7377                 0.162908                  0.003280
# 7378                 0.093068                  0.004288
# 7379                 0.094164                  0.005896
# 7380                 0.118464                  0.003952
#
#       Volume Flow RateRMS_Fluctuation  Hydraulic_Power_Fluctuation  \
# 0                            0.285160                     8.584219
# 1                            0.038412                    16.180027
# 2                            0.199256                    12.170266
# 3                            0.310260                     8.450375
# 4                            0.320000                    21.923342
# ...                               ...                          ...
# 7376                         0.312968                    18.169994
# 7377                         0.386440                    39.007200
# 7378                         0.376272                     7.216541
# 7379                         0.459960                    39.482278
# 7380                         0.330628                     3.127445
#
#       Electrical_Power_Fluctuation              description  anomaly
# 0                       126.989244               No Anomaly      0.0
# 1                        34.680405               No Anomaly      0.0
# 2                        28.633766               No Anomaly      0.0
# 3                         7.272027  Inlet Valve Malfunction     12.0
# 4                        83.523038               No Anomaly      0.0
# ...                            ...                      ...      ...
# 7376                     43.781339  Inlet Valve Malfunction     12.0
# 7377                     33.850955               No Anomaly      0.0
# 7378                     31.761236               No Anomaly      0.0
# 7379                    107.722079               No Anomaly      0.0
# 7380                     25.318815               No Anomaly      0.0
#
# [7381 rows x 30 columns]

# %%
adasyn = ADASYN(random_state=SEED)
X_res_adasyn, y_res_adasyn = adasyn.fit_resample(dataframe_train.drop(columns=["anomaly", "description"]), dataframe_train.anomaly.values)

X_res_adasyn.shape, y_res_adasyn.shape
# Out:
# ((73798, 28), (73798,))

# %%
dataframe_train_adasyn = pd.DataFrame(X_res_adasyn, columns=dataframe_train.drop(columns=["anomaly", "description"]).columns)
dataframe_train_adasyn["anomaly"] = y_res_adasyn

dataframe_train_adasyn
# Out:
#        Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  Temperature  \
# 0               0.210323           0.262893  2.658640  1.074847    88.621700
# 1               0.028297           0.042536  0.814120  0.745430    68.031800
# 2               0.028185           0.041387  0.810610  1.073357    68.875000
# 3               0.027955           0.042217  1.125930  1.073357    68.997300
# 4               0.211749           0.272061  2.654510  1.402774    90.273900
# ...                  ...                ...       ...       ...          ...
# 73793           0.027429           0.041699  1.325212  0.863596    68.629762
# 73794           0.027483           0.041980  1.315788  0.745430    68.470104
# 73795           0.027817           0.038316  1.252475  0.745430    68.069963
# 73796           0.027834           0.038128  1.249346  0.745430    68.050351
# 73797           0.027567           0.040426  1.317987  0.745430    68.482225
#
#        Thermocouple     Voltage  Volume Flow RateRMS  Electrical_Resistence  \
# 0         29.314700  230.091000           126.677000              86.544624
# 1         24.235400  232.174000            32.000000             285.184002
# 2         24.707500  208.422000            32.000000             257.117479
# 3         24.767900  235.556000            27.000000             209.210164
# 4         27.847300  225.678000           123.668000              85.016820
# ...             ...         ...                  ...                    ...
# 73793     24.270325  231.802778            29.014486             174.939054
# 73794     24.260493  231.655506            29.307019             176.062075
# 73795     24.193139  227.590941            30.756331             181.749663
# 73796     24.189266  227.381478            30.845884             182.024923
# 73797     24.288311  235.865130            30.385064             178.949368
#
#        Flow_Resistance  ...  AccelerometerRMS_pu_Pressure  \
# 0             0.008485  ...                      0.000436
# 1             0.023295  ...                      0.000038
# 2             0.033542  ...                      0.000036
# 3             0.039754  ...                      0.000044
# 4             0.011343  ...                      0.000466
# ...                ...  ...                           ...
# 73793         0.029761  ...                      0.000039
# 73794         0.025458  ...                      0.000039
# 73795         0.024248  ...                      0.000035
# 73796         0.024174  ...                      0.000034
# 73797         0.024591  ...                      0.000037
#
#        Engine_Temperature_pu_Power  Efficiency_Temperature_Difference_Ratio  \
# 0                         0.170436                                 0.007359
# 1                         0.423439                                 0.005650
# 2                         0.479609                                 0.009025
# 3                         0.306061                                 0.004844
# 4                         0.177284                                 0.009096
# ...                            ...                                      ...
# 73793                     0.262864                                 0.003595
# 73794                     0.264277                                 0.003178
# 73795                     0.281060                                 0.003598
# 73796                     0.281902                                 0.003621
# 73797                     0.259278                                 0.003231
#
#        AccelerometerRMS_Fluctuation  Temperature_Fluctuation  \
# 0                          0.000450                 0.115096
# 1                          0.000042                 0.111232
# 2                          0.000026                 0.029276
# 3                          0.000024                 0.018756
# 4                          0.000340                 0.075920
# ...                             ...                      ...
# 73793                      0.000025                 0.066525
# 73794                      0.000022                 0.048305
# 73795                      0.000038                 0.044370
# 73796                      0.000039                 0.044494
# 73797                      0.000023                 0.074966
#
#        Thermocouple_Fluctuation  Volume Flow RateRMS_Fluctuation  \
# 0                      0.005824                         0.285160
# 1                      0.004348                         0.038412
# 2                      0.006124                         0.199256
# 3                      0.002284                         0.310260
# 4                      0.004140                         0.320000
# ...                         ...                              ...
# 73793                  0.003565                         0.490804
# 73794                  0.002379                         0.379397
# 73795                  0.003823                         0.402793
# 73796                  0.003904                         0.404057
# 73797                  0.002898                         0.375677
#
#        Hydraulic_Power_Fluctuation  Electrical_Power_Fluctuation  anomaly
# 0                         8.584219                    126.989244      0.0
# 1                        16.180027                     34.680405      0.0
# 2                        12.170266                     28.633766      0.0
# 3                         8.450375                      7.272027     12.0
# 4                        21.923342                     83.523038      0.0
# ...                            ...                           ...      ...
# 73793                     9.464035                     16.592948     13.0
# 73794                     8.818340                     14.141227     13.0
# 73795                    14.609254                     18.288581     13.0
# 73796                    14.893898                     18.561562     13.0
# 73797                     9.626558                     19.898287     13.0
#
# [73798 rows x 29 columns]

# %%
columns = dataframe_train.drop(columns=["anomaly", "description"]).columns
for idx, col in enumerate(columns):
    print(f"{idx}: {col}")
# Out:
# 0: Accelerometer1RMS
# 1: Accelerometer2RMS
# 2: Current
# 3: Pressure
# 4: Temperature
# 5: Thermocouple
# 6: Voltage
# 7: Volume Flow RateRMS
# 8: Electrical_Resistence
# 9: Flow_Resistance
# 10: Temperature_EbyF
# 11: AccelerometerRMS
# 12: Specific_Power
# 13: Accelerometer_Balance
# 14: Temperature_Difference
# 15: Hydraulic_Power
# 16: Electrical_Power
# 17: Actual_Efficiency
# 18: Vibration_Intensity_Ratio
# 19: AccelerometerRMS_pu_Pressure
# 20: Engine_Temperature_pu_Power
# 21: Efficiency_Temperature_Difference_Ratio
# 22: AccelerometerRMS_Fluctuation
# 23: Temperature_Fluctuation
# 24: Thermocouple_Fluctuation
# 25: Volume Flow RateRMS_Fluctuation
# 26: Hydraulic_Power_Fluctuation
# 27: Electrical_Power_Fluctuation

# %%
col1, col2 = columns[6], columns[16]

fig, axs = plt.subplots(1, 2, figsize=(20, 6), dpi=PLOT_DPI)

axs[0].set_title("Original Imbalanced Dataset")
for class_label in np.unique(dataframe_train.anomaly):
    axs[0].scatter(
                    dataframe_train[dataframe_train.anomaly == class_label][col1], 
                    dataframe_train[dataframe_train.anomaly == class_label][col2], 
                    label=f'Class {class_label}', alpha=0.5, s=20 if class_label == 0 else 40
    )
axs[0].legend()
axs[0].grid(True, linestyle='--', alpha=0.6)

axs[1].set_title("Dataset after adasyn")
for class_label in np.unique(dataframe_train_adasyn.anomaly):
    axs[1].scatter(
                    dataframe_train_adasyn[dataframe_train_adasyn.anomaly == class_label][col1], 
                    dataframe_train_adasyn[dataframe_train_adasyn.anomaly == class_label][col2], 
                    label=f'Class {class_label}', alpha=0.5, s=20 if class_label == 0 else 40
    )
axs[1].legend()
axs[1].grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
